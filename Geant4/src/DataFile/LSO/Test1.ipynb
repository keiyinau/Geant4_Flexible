# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 
import mplhep as hep 
import uproot
from scipy.stats import bootstrap

plt.style.use(hep.style.CMS)

# %%
dat=pd.read_csv("EmissionSpectrum_LSO_Ce_295K.csv",header=None)
plt.plot(dat[0],dat[1],"o-")

# %%
dat=pd.read_csv("AbsorptionLength_LSO_Ce.txt",header=None,delim_whitespace=True)
plt.plot(dat[0],dat[1],"o-")
# Out:
# /tmp/ipykernel_163263/3721388329.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dat=pd.read_csv("AbsorptionLength_LSO_Ce.txt",header=None,delim_whitespace=True)

# %%
dat=pd.read_csv("RefractiveIndex_LSO_Ce.txt",header=None,delim_whitespace=True)
plt.plot(dat[0],dat[1],"o-")
# Out:
# /tmp/ipykernel_163263/3748419501.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dat=pd.read_csv("RefractiveIndex_LSO_Ce.txt",header=None,delim_whitespace=True)
