# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 
import mplhep as hep 
import uproot
from scipy.stats import bootstrap

plt.style.use(hep.style.CMS)

# %%
dat=pd.read_csv("EmissionSpectrum_LYSO_Ce_Relative.csv",delimiter="\t",header=None)
dat[1]=dat[1]/dat[1].sum()
dat=dat[dat[1]>0]
dat.to_csv("EmissionSpectrum_LYSO_Ce.csv",index=False,header=False,sep=",")

# %%
dat=pd.read_csv("AbsorptionCoefficient_LYSO_Ce.txt",delimiter="\t",header=None)
dat[1]=1/dat[1]
dat.to_csv("AbsorptionLength_LYSO_Ce.txt",index=False,header=False,sep="\t")

# %%
dat=pd.read_csv("Nonproportionality_LYSO_Ce.txt",delimiter="\t",header=None)
dat[1]=dat[1]/100
dat.to_csv("Nonproportionality_LYSO_Ce_Relative.txt",index=False,header=False,sep="\t")

# %%
dat[1]=dat[1]/100
